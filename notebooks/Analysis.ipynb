# %% [markdown]
# # Algorithm Complexity Analysis:
#
# Linear Character Swap - Breadth First vs. Depth First for secret key guessing

# %% [markdown]
# ## Problem Description
#
# You found a box containing THE book "How to earn HDs for every course at RMIT with only 5-minute self-learning per day". It's very very very precious, isn't it? However, to open the box you need to know a secret key that is used to unlock the box. By looking at the lock pattern, you know that the secret key contains 16 letters, each can be either "R", "M", "I" or "T". You can calculate how many combinations there are. If each try takes you one second, do you want to try?
#
# Fortunately, you have a hack that: given a guessed secret key, it returns the number of positions that are matched between the guessed key and the correct key. For example (I used only 4 letters here for demonstration purposes only), if the correct secret key is "RMIT" and you guess "MMIT", the last three positions are correct, so 3 is returned. If you guess "TRMI", zero is returned. If you guess "RRRR", 1 is returned. And if you guess "RMIT", 4 is returned. Of course, in your case, you want to have 16 returned.
#
# The correct secret key contains exactly 16 letters, each of which must be either "R", "M", "I", or "T".
#
# You must minimize the number of guess made to reach the correct secret key.

# %%
# Imports and environmental setups

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %% [markdown]
# ## Guesses Count Performance
#
# This is the test results for guesses count performance for each of the algorithm over 1 million pseudo-random test secret key of length 16.
#
# Test code (abbreviated):
#
# ```java
#     final int MAX_ITER = 1_000_000;
#     final int KEY_LEN = 16;
#
#     for (int i = 0; i < MAX_ITER; i++) {
#         SecretKey sk = new SecretKey(KEY_LEN, i);  // Reproducible results for consistent performance measurement.
#         SecretKeyGuesser.start(sk, KEY_LEN, SecretKeyGuesser.Algorithm.(...), false);
#     }
# ```

# %%
guessData = {
    "Auto": pd.read_csv("../testData/randomKey16TestAuto.csv"),
    "DepthFirst": pd.read_csv("../testData/randomKey16TestDepthFirst.csv"),
    "BreadthFirst": pd.read_csv("../testData/randomKey16TestBreadthFirst.csv")
}

def plot_performance(x_col: str, title: str, save_path: str = None) -> None:
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))

    sns.scatterplot(
        x=guessData["Auto"][x_col], y=guessData["Auto"]["GuessCount"], ax=ax,
        marker="o", linewidth=0.5, alpha=0.2, color="red", s=30
    )
    sns.scatterplot(
        x=guessData["DepthFirst"][x_col], y=guessData["DepthFirst"]["GuessCount"], ax=ax,
        marker="x", linewidth=0.5, alpha=0.2, color="green", s=50
    )
    sns.scatterplot(
        x=guessData["BreadthFirst"][x_col], y=guessData["BreadthFirst"]["GuessCount"], ax=ax,
        marker="+", linewidth=1, alpha=0.2, color="blue", s=50
    )

    sns.lineplot(
        x=guessData["Auto"][x_col], y=guessData["Auto"]["GuessCount"], ax=ax,
        c="red", alpha=0.3, errorbar="sd",
        label=f"Auto (max={guessData['Auto']['GuessCount'].max()}, "
              f"min={guessData['Auto']['GuessCount'].min()}, "
              f"mean={guessData['Auto']['GuessCount'].mean()})",
        linestyle="--"
    )
    sns.lineplot(
        x=guessData["DepthFirst"][x_col], y=guessData["DepthFirst"]["GuessCount"], ax=ax,
        c="green", alpha=0.3, errorbar="sd",
        label=f"DepthFirst (max={guessData['DepthFirst']['GuessCount'].max()}, "
              f"min={guessData['DepthFirst']['GuessCount'].min()}, "
              f"mean={guessData['DepthFirst']['GuessCount'].mean()})"
    )
    sns.lineplot(
        x=guessData["BreadthFirst"][x_col], y=guessData["BreadthFirst"]["GuessCount"], ax=ax,
        c="blue", alpha=0.3, errorbar="sd",
        label=f"BreadthFirst (max={guessData['BreadthFirst']['GuessCount'].max()}, "
              f"min={guessData['BreadthFirst']['GuessCount'].min()}, "
              f"mean={guessData['BreadthFirst']['GuessCount'].mean()})"
    )

    ax.legend()
    fig.suptitle(title, fontsize=18, fontweight="bold")
    fig.tight_layout()

    plt.show()
    if save_path is not None:
        fig.savefig(save_path)

# %%
plot_performance("CharFreqRange", "Guess Performance by Character Frequency Range", "images/GuessCountByRange.png")

# %%
plot_performance("CharFreqMean", "Guess Performance by Character Frequency Mean", "images/GuessCountByMean.png")

# %%
plot_performance("CharFreqMedian", "Guess Performance by Character Frequency Median", "images/GuessCountByMedian.png")

# %%
plot_performance("CharFreqVariance", "Guess Performance by Character Frequency Variance", "images/GuessCountByVariance.png")

# %%
plot_performance("CharFreqStdDev", "Guess Performance by Character Frequency Standard Deviation", "images/GuessCountByStdDev.png")

# %% [markdown]
# ### Most Significant Statistical Properties of Secret Key's Character Frequency:
#
# We are looking for properties that result in significantly different performance between our algorithms.
#
# - Character Frequency Range
# - Character Frequency Median
# - Character Frequency Variance

# %%
x_cols = ["CharFreqRange", "CharFreqMedian", "CharFreqVariance"]
thresholds = [5, 5, 10]


fig, ax = plt.subplots(nrows=1, ncols=len(x_cols), sharey="all", figsize=(15, 6))

sns.scatterplot(
    x=guessData["Auto"][x_cols[0]], y=guessData["Auto"]["GuessCount"], ax=ax[0],
    marker="o", linewidth=0.5, alpha=0.2, color="red", s=15,
    legend=False
)
sns.scatterplot(
    x=guessData["DepthFirst"][x_cols[0]], y=guessData["DepthFirst"]["GuessCount"], ax=ax[0],
    marker="x", linewidth=0.5, alpha=0.2, color="green", s=25,
    legend=False
)
sns.scatterplot(
    x=guessData["BreadthFirst"][x_cols[0]], y=guessData["BreadthFirst"]["GuessCount"], ax=ax[0],
    marker="+", linewidth=1, alpha=0.2, color="blue", s=25,
    legend=False
)

sns.lineplot(
    x=guessData["Auto"][x_cols[0]], y=guessData["Auto"]["GuessCount"], ax=ax[0],
    c="red", alpha=0.3, errorbar="sd",
    label=f"Auto (max={guessData['Auto']['GuessCount'].max()}, "
          f"min={guessData['Auto']['GuessCount'].min()}, "
          f"mean={guessData['Auto']['GuessCount'].mean()})",
    linestyle="--",
    legend=False
)
sns.lineplot(
    x=guessData["DepthFirst"][x_cols[0]], y=guessData["DepthFirst"]["GuessCount"], ax=ax[0],
    c="green", alpha=0.3, errorbar="sd",
    label=f"DepthFirst (max={guessData['DepthFirst']['GuessCount'].max()}, "
          f"min={guessData['DepthFirst']['GuessCount'].min()}, "
          f"mean={guessData['DepthFirst']['GuessCount'].mean()})",
    legend=False
)
sns.lineplot(
    x=guessData["BreadthFirst"][x_cols[0]], y=guessData["BreadthFirst"]["GuessCount"], ax=ax[0],
    c="blue", alpha=0.3, errorbar="sd",
    label=f"BreadthFirst (max={guessData['BreadthFirst']['GuessCount'].max()}, "
          f"min={guessData['BreadthFirst']['GuessCount'].min()}, "
          f"mean={guessData['BreadthFirst']['GuessCount'].mean()})",
    legend=False
)

ax[0].axvline(x=thresholds[0], c="gold", label="Threshold")

for i in range(1, len(x_cols)):
    sns.scatterplot(
        x=guessData["Auto"][x_cols[i]], y=guessData["Auto"]["GuessCount"], ax=ax[i],
        marker="o", linewidth=0.5, alpha=0.2, color="red", s=15,
        legend=False
    )
    sns.scatterplot(
        x=guessData["DepthFirst"][x_cols[i]], y=guessData["DepthFirst"]["GuessCount"], ax=ax[i],
        marker="x", linewidth=0.5, alpha=0.2, color="green", s=25,
        legend=False
    )
    sns.scatterplot(
        x=guessData["BreadthFirst"][x_cols[i]], y=guessData["BreadthFirst"]["GuessCount"], ax=ax[i],
        marker="+", linewidth=1, alpha=0.2, color="blue", s=25,
        legend=False
    )

    sns.lineplot(
        x=guessData["Auto"][x_cols[i]], y=guessData["Auto"]["GuessCount"], ax=ax[i],
        c="red", alpha=0.3, errorbar="sd",
        legend=False
    )
    sns.lineplot(
        x=guessData["DepthFirst"][x_cols[i]], y=guessData["DepthFirst"]["GuessCount"], ax=ax[i],
        c="green", alpha=0.3, errorbar="sd",
        legend=False
    )
    sns.lineplot(
        x=guessData["BreadthFirst"][x_cols[i]], y=guessData["BreadthFirst"]["GuessCount"], ax=ax[i],
        c="blue", alpha=0.3, errorbar="sd",
        legend=False
    )

    ax[i].axvline(x=thresholds[i], c="gold")

fig.legend(loc="outside lower center", ncol=2, bbox_to_anchor=(0.5, -0.1), frameon=False)
fig.suptitle("Guess Performance", fontsize=18, fontweight="bold")
fig.subplots_adjust(bottom=0.2)
fig.tight_layout()

plt.show()
fig.savefig("images/GuessCountPerformanceReport.png", bbox_inches="tight")

# %% [markdown]
# ### ☞ Observation
#
# - Depth First Algorithm's best performance range:
#     - $CharFreqRange < 5$
#     - $CharFreqMedian < 5$
#     - $CharFreqVariance < 10$
# - Breadth First Algorithm's best performance range:
#     - $CharFreqRange >= 5$
#     - $CharFreqMedian >= 5$
#     - $CharFreqVariance >= 10$
#
# Given the length of the secret key is $n = 16$, we can extrapolate that the best threshold for our Auto algorithm is:
#
# - $T_{range} = n / 3.2$ or
# - $T_{median} = n / 3.2$ or
# - $T_{variance} = (n / 5)^2$
#
# Our Auto algorithm seems to have been well optimized to use each of the above algorithm for their best cases.

# %% [markdown]
# ### Correlation between Statistical Properties of Secret Key's Character Frequency

# %%
plt.figure(figsize=(16, 16))

sns.pairplot(
    guessData["Auto"].drop(["Iteration", "CharFreqMean", "CharFreqStdDev", "GuessCount"], axis=1),
    diag_kind="hist",
    plot_kws=dict(marker="x", linewidth=0.5, alpha=0.2, color="crimson", s=10),
    diag_kws=dict(bins=16, alpha=0.3, color="dodgerblue")
)

plt.show()

# %% [markdown]
# ### ☞ Observation
#
# All 3 properties are very closely correlated, which is to be expected considering their [definition and formulae](https://www.calculatorsoup.com/calculators/statistics/descriptivestatistics.php). This means we can just use 1 of the 3 to find the optimal policy for our Auto algorithm for when to use Breadth First and when to use Depth First.

# %% [markdown]
# ## Time Complexity
#
# This is the time complexity test results for each algorithm. Since we can see that both of them are $O(n)$ based on [their code](../src/main/java/vn/rmit/cosc2658/development/SecretKeyGuesser.java), the overall time complexity should also be $O(n)$.
#
# Test code (abbreviated):
#
# ```java
#     final int MAX_KEY_LENGTH = 512;
#
#     for (int keyLength = 1; keyLength <= MAX_KEY_LENGTH; keyLength++) {
#         SecretKey sk = new SecretKey(keyLength, 0);  // Seed = 0 to ensure reproducible results
#         SecretKeyGuesser.start(sk, keyLength, SecretKeyGuesser.Algorithm.(...), false);
#     }
# ```

# %%
timeData = {
    "Auto": pd.read_csv("../testData/randomKeyVariableLengthTestAuto.csv"),
    "DepthFirst": pd.read_csv("../testData/randomKeyVariableLengthTestDepthFirst.csv"),
    "BreadthFirst": pd.read_csv("../testData/randomKeyVariableLengthTestBreadthFirst.csv")
}

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, sharex="all", figsize=(8, 14))

sns.lineplot(
    x=timeData["Auto"]["KeyLength"], y=timeData["Auto"]["RunTime"], ax=ax[0],
    c="red", alpha=0.3,
    label=f"Auto\nMax: {timeData['Auto']['RunTime'].max()}", linestyle="--"
)
sns.lineplot(
    x=timeData["Auto"]["KeyLength"], y=timeData["Auto"]["GuessCount"], ax=ax[1],
    c="red", alpha=0.3,
    label=f"Auto\nMax: {timeData['Auto']['GuessCount'].max()}", linestyle="--"
)

sns.lineplot(
    x=timeData["DepthFirst"]["KeyLength"],y=timeData["DepthFirst"]["RunTime"], ax=ax[0],
    c="green", alpha=0.3,
    label=f"DepthFirst\nMax: {timeData['DepthFirst']['RunTime'].max()}"
)
sns.lineplot(
    x=timeData["DepthFirst"]["KeyLength"], y=timeData["DepthFirst"]["GuessCount"], ax=ax[1],
    c="green", alpha=0.3,
    label=f"DepthFirst\nMax: {timeData['DepthFirst']['GuessCount'].max()}"
)

sns.lineplot(
    x=timeData["BreadthFirst"]["KeyLength"], y=timeData["BreadthFirst"]["RunTime"], ax=ax[0],
    c="blue", alpha=0.3,
    label=f"BreadthFirst\nMax: {timeData['BreadthFirst']['RunTime'].max()}"
)
sns.lineplot(
    x=timeData["BreadthFirst"]["KeyLength"], y=timeData["BreadthFirst"]["GuessCount"], ax=ax[1],
    c="blue", alpha=0.3,
    label=f"BreadthFirst\nMax: {timeData['BreadthFirst']['GuessCount'].max()}"
)

ax[0].legend(loc="upper left")
ax[1].legend(loc="upper left")

fig.suptitle("Runtime and Guess Count vs. Key Length", fontsize=18, fontweight="bold")
fig.tight_layout()

plt.show()
fig.savefig("images/TimeComplexity.png")

# %% [markdown]
# ### ☞ Observation
#
# - **Time Complexity**: Does not seem to be $O(n)$ as expected, but resembles $O(n^2)$ or $O(n \cdot log(n))$ more. This might be because:
#     1. The constants in our algorithm's time complexity analysis are much larger than we anticipated. For example, our algorithm might have a loop that is $O(n)$ in theory, but in practice, the loop has many expensive operations that cause it to take longer than expected.
#     2. Our implementation of the algorithm may not be optimal. It's possible that there are ways to optimize your code that we haven't thought of yet.
# - **Guess Complexity**: Linear $O(n)$, as expected, with some caveats:
#     1. Breadth First algorithm tends to have worse average guess performance as $keyLength$ grows because of how frequently it encounters its worst case.
#     2. Our Auto algorithm (dashed red line) seems to have effectively mitigated the above problem. Thus, it should have the best threshold $T$ already.
#
# **Note:** Auto algorithm automatically choose - based on the character frequency range - between either Depth First and Breadth First for best guess count performance. The threshold for switching is the above-mentioned $T$.
